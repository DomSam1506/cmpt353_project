# %% [markdown]
# # Game Dataset Cleaning
# This notebook prepares the RAWG-based video game dataset for analysis by:
# - Removing irrelevant or duplicate rows and columns
# - Properly parsing nested data (genres, platforms, stores)
# - Creating engineered features (platform type, rating gap, etc.)
# - Saving a cleaned version for further analysis

# %% [markdown]
# ### Load Data

# %%
import pandas as pd
import numpy as np
import sys
import ast

# For plotting functions
sys.path.append("..")

games = pd.read_csv("../data/games_data.csv")

games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  10000 non-null  int64
#  1   name                10000 non-null  object
#  2   released            9842 non-null   object
#  3   avg_user_rating     10000 non-null  float64
#  4   user_ratings_count  10000 non-null  int64
#  5   reviews_count       10000 non-null  int64
#  6   added               10000 non-null  int64
#  7   metacritic_rating   4250 non-null   float64
#  8   avg_playtime        10000 non-null  int64
#  9   genres              10000 non-null  object
#  10  platforms           10000 non-null  object
#  11  stores              10000 non-null  object
#  12  tags                10000 non-null  object
#  13  esrb_rating         4281 non-null   object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Check and Clean Basic Missing Values

# %%
# Check for missing values
print(games.isna().sum())

# Drop duplicates
games.drop_duplicates(inplace = True)

# Drop rows with non release date
games = games.dropna(subset= ['released']).copy()
# Out:
# id                       0
# name                     0
# released               158
# avg_user_rating          0
# user_ratings_count       0
# reviews_count            0
# added                    0
# metacritic_rating     5750
# avg_playtime             0
# genres                   0
# platforms                0
# stores                   0
# tags                     0
# esrb_rating           5719
# dtype: int64

# %% [markdown]
# ### Feature Engineering - Release Date Components

# %%
games['released'] = pd.to_datetime(games['released'], format = '%Y-%m-%d')

# Extract date components
games['release_year'] = games['released'].dt.year
games['release_month'] = games['released'].dt.month
games['release_quarter'] = games['released'].dt.quarter

# %% [markdown]
# ### Feature Engineering - Critic and User Rating Gap (Extra/Supplementary)

# %%
games['critic_rating'] = games['metacritic_rating'] / 20
games['rating_gap'] = games['avg_user_rating'] - games['critic_rating']

# %% [markdown]
# ### Genre Processing

# %%
games['genres'] = games['genres'].apply(ast.literal_eval)
games['genre_count'] = games['genres'].apply(len)


# Binarize Genres
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
encoded_genres = pd.DataFrame(mlb.fit_transform(games['genres']), columns=[f"is_{g.lower().replace(' ', '_')}" for g in mlb.classes_],
                             index=games.index)

games = pd.concat([games, encoded_genres], axis=1)
games.drop(columns=['genres'], inplace=True)

# %% [markdown]
# ### Platform Features

# %%
def platform_type(platforms):
    pc = any('PC' in p for p in platforms)
    console = any(any(c in p for c in ['PlayStation', 'Xbox', 'Nintendo']) for p in platforms)

    if pc and not console:
        return 'pc_only'
    elif console and not pc:
        return 'console_only'
    elif pc and console:
        return 'multi_platform'
    else:
        return 'other' 
    
    
games['platforms'] = games['platforms'].apply(ast.literal_eval)
games['platform_type'] = games['platforms'].apply(platform_type)
games['platform_count'] =  games['platforms'].apply(len)

# %% [markdown]
# ### Store Features

# %%
games['stores'] = games['stores'].apply(ast.literal_eval)
games['store_count'] = games['stores'].apply(len)

# %% [markdown]
# ### Drop unneeded columns and Metadata errors from API

# %%
games.drop(columns = ['released', 'metacritic_rating','tags', 'stores', 'platforms'], inplace= True)

# Metadata error
games = games[games['genre_count'] != 0]
games = games[games['store_count']!= 0]
games = games[games['platform_count'] != 0]

# Games only before 2025 to remove skew
games= games[games['release_year']< 2025]

# Only keep games with at least 10 user ratings
games = games[games['user_ratings_count'] >= 10]

games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8122 entries, 0 to 9999
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        8122 non-null   int64
#  1   name                      8122 non-null   object
#  2   avg_user_rating           8122 non-null   float64
#  3   user_ratings_count        8122 non-null   int64
#  4   reviews_count             8122 non-null   int64
#  5   added                     8122 non-null   int64
#  6   avg_playtime              8122 non-null   int64
#  7   esrb_rating               3904 non-null   object
#  8   release_year              8122 non-null   int32
#  9   release_month             8122 non-null   int32
#  10  release_quarter           8122 non-null   int32
#  11  critic_rating             3956 non-null   float64
#  12  rating_gap                3956 non-null   float64
#  13  genre_count               8122 non-null   int64
#  14  is_action                 8122 non-null   int64
#  15  is_adventure              8122 non-null   int64
#  16  is_arcade                 8122 non-null   int64
#  17  is_board_games            8122 non-null   int64
#  18  is_card                   8122 non-null   int64
#  19  is_casual                 8122 non-null   int64
#  20  is_educational            8122 non-null   int64
#  21  is_family                 8122 non-null   int64
#  22  is_fighting               8122 non-null   int64
#  23  is_indie                  8122 non-null   int64
#  24  is_massively_multiplayer  8122 non-null   int64
#  25  is_platformer             8122 non-null   int64
#  26  is_puzzle                 8122 non-null   int64
#  27  is_rpg                    8122 non-null   int64
#  28  is_racing                 8122 non-null   int64
#  29  is_shooter                8122 non-null   int64
#  30  is_simulation             8122 non-null   int64
#  31  is_sports                 8122 non-null   int64
#  32  is_strategy               8122 non-null   int64
#  33  platform_type             8122 non-null   object
#  34  platform_count            8122 non-null   int64
#  35  store_count               8122 non-null   int64
# dtypes: float64(3), int32(3), int64(27), object(3)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Inspect and Save Cleaned Data

# %%
games.head(20)
# Out:
#        id                              name  avg_user_rating  \
# 0    3498                Grand Theft Auto V             4.47
# 1    3328          The Witcher 3: Wild Hunt             4.64
# 2    4200                          Portal 2             4.59
# 3    4291  Counter-Strike: Global Offensive             3.57
# 4    5286                Tomb Raider (2013)             4.06
# 5   13536                            Portal             4.49
# 6   12020                     Left 4 Dead 2             4.09
# 7    5679       The Elder Scrolls V: Skyrim             4.42
# 8      28             Red Dead Redemption 2             4.59
# 9    4062                 BioShock Infinite             4.38
# 10  13537                       Half-Life 2             4.48
# 11    802                     Borderlands 2             4.01
# 12   3439                   Life is Strange             4.12
# 13   4286                          BioShock             4.36
# 14     32                         Destiny 2             3.52
# 15  58175                 God of War (2018)             4.55
# 16   3070                         Fallout 4             3.81
# 17   3939                          PAYDAY 2             3.52
# 18   1030                             Limbo             4.14
# 19  11859                   Team Fortress 2             3.68
#
#     user_ratings_count  reviews_count  added  avg_playtime   esrb_rating  \
# 0                 7160           7275  22138            74        Mature
# 1                 6964           7077  21799            43        Mature
# 2                 5942           5998  20628            11  Everyone 10+
# 3                 3586           3624  18286            64        Mature
# 4                 4022           4054  17635            10        Mature
# 5                 4898           4942  17587             4          Teen
# 6                 3356           3381  17401             9        Mature
# 7                 4803           4856  16596            46        Mature
# 8                 5296           5420  16462            21        Mature
# 9                 4122           4164  15967            12        Mature
# 10                3996           4021  15901             7        Mature
# 11                3261           3281  15868            11        Mature
# 12                3717           3764  15793             6        Mature
# 13                3323           3367  14636             3        Mature
# 14                2648           2674  14542             6          Teen
# 15                5002           5109  14234            15        Mature
# 16                3362           3395  14126            38        Mature
# 17                2218           2239  14101             9   Adults Only
# 18                3340           3380  14019             3          Teen
# 19                2911           2940  13971             8        Mature
#
#     release_year  release_month  ...  is_puzzle  is_rpg  is_racing  \
# 0           2013              9  ...          0       0          0
# 1           2015              5  ...          0       1          0
# 2           2011              4  ...          1       0          0
# 3           2012              8  ...          0       0          0
# 4           2013              3  ...          0       0          0
# 5           2007             10  ...          1       0          0
# 6           2009             11  ...          0       0          0
# 7           2011             11  ...          0       1          0
# 8           2018             10  ...          0       0          0
# 9           2013              3  ...          0       0          0
# 10          2004             11  ...          0       0          0
# 11          2012              9  ...          0       1          0
# 12          2015              1  ...          0       0          0
# 13          2007              8  ...          0       0          0
# 14          2017              9  ...          0       0          0
# 15          2018              4  ...          0       0          0
# 16          2015             11  ...          0       1          0
# 17          2013              8  ...          0       0          0
# 18          2010              7  ...          1       0          0
# 19          2007             10  ...          0       0          0
#
#     is_shooter  is_simulation  is_sports  is_strategy   platform_type  \
# 0            0              0          0            0  multi_platform
# 1            0              0          0            0  multi_platform
# 2            1              0          0            0  multi_platform
# 3            1              0          0            0  multi_platform
# 4            0              0          0            0  multi_platform
# 5            0              0          0            0  multi_platform
# 6            1              0          0            0  multi_platform
# 7            0              0          0            0  multi_platform
# 8            0              0          0            0  multi_platform
# 9            1              0          0            0  multi_platform
# 10           1              0          0            0  multi_platform
# 11           1              0          0            0  multi_platform
# 12           0              0          0            0  multi_platform
# 13           1              0          0            0  multi_platform
# 14           1              0          0            0  multi_platform
# 15           0              0          0            0  multi_platform
# 16           0              0          0            0  multi_platform
# 17           1              0          0            0  multi_platform
# 18           0              0          0            0  multi_platform
# 19           1              0          0            0         pc_only
#
#     platform_count  store_count
# 0                7            5
# 1                7            5
# 2                6            4
# 3                4            3
# 4                6            6
# 5                7            2
# 6                4            2
# 7                8            4
# 8                3            4
# 9                7            7
# 10               6            2
# 11               7            6
# 12               9            7
# 13               4            5
# 14               6            4
# 15               2            4
# 16               4            3
# 17               3            5
# 18              11            9
# 19               3            1
#
# [20 rows x 36 columns]

# %%
games.to_csv("..\data\games_data_cleaned.csv", index = False)
